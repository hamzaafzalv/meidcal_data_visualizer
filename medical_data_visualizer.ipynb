# %%
import pandas as pd

# %%
df =pd.read_csv('medical_examination.csv')

# %%
df
# Out:
#           id    age  sex  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393    2     168    62.0    110     80            1     1
# 1          1  20228    1     156    85.0    140     90            3     1
# 2          2  18857    1     165    64.0    130     70            3     1
# 3          3  17623    2     169    82.0    150    100            1     1
# 4          4  17474    1     156    56.0    100     60            1     1
# ...      ...    ...  ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240    2     168    76.0    120     80            1     1
# 69996  99995  22601    1     158   126.0    140     90            2     2
# 69997  99996  19066    2     183   105.0    180     90            3     1
# 69998  99998  22431    1     163    72.0    135     80            1     2
# 69999  99999  20540    1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# 0          0     0       1       0
# ...

# %%
overweight = ''
df['overweight'] = overweight
df
# Out:
#           id    age  sex  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393    2     168    62.0    110     80            1     1
# 1          1  20228    1     156    85.0    140     90            3     1
# 2          2  18857    1     165    64.0    130     70            3     1
# 3          3  17623    2     169    82.0    150    100            1     1
# 4          4  17474    1     156    56.0    100     60            1     1
# ...      ...    ...  ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240    2     168    76.0    120     80            1     1
# 69996  99995  22601    1     158   126.0    140     90            2     2
# 69997  99996  19066    2     183   105.0    180     90            3     1
# 69998  99998  22431    1     163    72.0    135     80            1     2
# 69999  99999  20540    1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio overweight
# ...

# %%
height_meter = df['height']/100
height_meter
df['height'] = height_meter
df
# Out:
#           id    age  sex  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393    2    1.68    62.0    110     80            1     1
# 1          1  20228    1    1.56    85.0    140     90            3     1
# 2          2  18857    1    1.65    64.0    130     70            3     1
# 3          3  17623    2    1.69    82.0    150    100            1     1
# 4          4  17474    1    1.56    56.0    100     60            1     1
# ...      ...    ...  ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240    2    1.68    76.0    120     80            1     1
# 69996  99995  22601    1    1.58   126.0    140     90            2     2
# 69997  99996  19066    2    1.83   105.0    180     90            3     1
# 69998  99998  22431    1    1.63    72.0    135     80            1     2
# 69999  99999  20540    1    1.70    72.0    120     80            2     1
#
#        smoke  alco  active  cardio overweight
# ...

# %%
BMI = df['weight']/df['height']*df['height'] #BMI
BMI
df['BMI'] = BMI
df
# Out:
#           id    age  sex  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393    2    1.68    62.0    110     80            1     1
# 1          1  20228    1    1.56    85.0    140     90            3     1
# 2          2  18857    1    1.65    64.0    130     70            3     1
# 3          3  17623    2    1.69    82.0    150    100            1     1
# 4          4  17474    1    1.56    56.0    100     60            1     1
# ...      ...    ...  ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240    2    1.68    76.0    120     80            1     1
# 69996  99995  22601    1    1.58   126.0    140     90            2     2
# 69997  99996  19066    2    1.83   105.0    180     90            3     1
# 69998  99998  22431    1    1.63    72.0    135     80            1     2
# 69999  99999  20540    1    1.70    72.0    120     80            2     1
#
#        smoke  alco  active  cardio overweight    BMI
# ...

# %%
df.loc[df['BMI'] > 25, 'overweight'] = 1
df.loc[df['BMI'] < 25, 'overweight'] = 0
df
# Out:
#           id    age  sex  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393    2    1.68    62.0    110     80            1     1
# 1          1  20228    1    1.56    85.0    140     90            3     1
# 2          2  18857    1    1.65    64.0    130     70            3     1
# 3          3  17623    2    1.69    82.0    150    100            1     1
# 4          4  17474    1    1.56    56.0    100     60            1     1
# ...      ...    ...  ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240    2    1.68    76.0    120     80            1     1
# 69996  99995  22601    1    1.58   126.0    140     90            2     2
# 69997  99996  19066    2    1.83   105.0    180     90            3     1
# 69998  99998  22431    1    1.63    72.0    135     80            1     2
# 69999  99999  20540    1    1.70    72.0    120     80            2     1
#
#        smoke  alco  active  cardio overweight    BMI
# ...

# %%
df
# Out:
#           id    age  sex  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393    2    1.68    62.0    110     80            1     1
# 1          1  20228    1    1.56    85.0    140     90            3     1
# 2          2  18857    1    1.65    64.0    130     70            3     1
# 3          3  17623    2    1.69    82.0    150    100            1     1
# 4          4  17474    1    1.56    56.0    100     60            1     1
# ...      ...    ...  ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240    2    1.68    76.0    120     80            1     1
# 69996  99995  22601    1    1.58   126.0    140     90            2     2
# 69997  99996  19066    2    1.83   105.0    180     90            3     1
# 69998  99998  22431    1    1.63    72.0    135     80            1     2
# 69999  99999  20540    1    1.70    72.0    120     80            2     1
#
#        smoke  alco  active  cardio overweight    BMI
# ...

# %%
df.loc[(df['gluc'] == 1) ,'gluc'] = 0
df
# Out:
#           id    age  sex  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393    2    1.68    62.0    110     80            1     0
# 1          1  20228    1    1.56    85.0    140     90            3     0
# 2          2  18857    1    1.65    64.0    130     70            3     0
# 3          3  17623    2    1.69    82.0    150    100            1     0
# 4          4  17474    1    1.56    56.0    100     60            1     0
# ...      ...    ...  ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240    2    1.68    76.0    120     80            1     0
# 69996  99995  22601    1    1.58   126.0    140     90            2     2
# 69997  99996  19066    2    1.83   105.0    180     90            3     0
# 69998  99998  22431    1    1.63    72.0    135     80            1     2
# 69999  99999  20540    1    1.70    72.0    120     80            2     0
#
#        smoke  alco  active  cardio overweight    BMI
# ...

# %%
df.loc[(df['gluc'] > 1) ,'gluc'] = 1
df
# Out:
#           id    age  sex  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393    2    1.68    62.0    110     80            1     0
# 1          1  20228    1    1.56    85.0    140     90            3     0
# 2          2  18857    1    1.65    64.0    130     70            3     0
# 3          3  17623    2    1.69    82.0    150    100            1     0
# 4          4  17474    1    1.56    56.0    100     60            1     0
# ...      ...    ...  ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240    2    1.68    76.0    120     80            1     0
# 69996  99995  22601    1    1.58   126.0    140     90            2     1
# 69997  99996  19066    2    1.83   105.0    180     90            3     0
# 69998  99998  22431    1    1.63    72.0    135     80            1     1
# 69999  99999  20540    1    1.70    72.0    120     80            2     0
#
#        smoke  alco  active  cardio overweight    BMI
# ...

# %%
df.loc[(df['cholesterol'] == 1) ,'cholesterol'] = 0
df.loc[(df['cholesterol'] > 1) ,'cholesterol'] = 1
df
# Out:
#           id    age  sex  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393    2    1.68    62.0    110     80            0     0
# 1          1  20228    1    1.56    85.0    140     90            1     0
# 2          2  18857    1    1.65    64.0    130     70            1     0
# 3          3  17623    2    1.69    82.0    150    100            0     0
# 4          4  17474    1    1.56    56.0    100     60            0     0
# ...      ...    ...  ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240    2    1.68    76.0    120     80            0     0
# 69996  99995  22601    1    1.58   126.0    140     90            1     1
# 69997  99996  19066    2    1.83   105.0    180     90            1     0
# 69998  99998  22431    1    1.63    72.0    135     80            0     1
# 69999  99999  20540    1    1.70    72.0    120     80            1     0
#
#        smoke  alco  active  cardio overweight    BMI
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
df_cat = pd.melt(df, id_vars = ['cardio'], value_vars = ['cholesterol','gluc','smoke','active','alco','overweight'])
df_cat
# Out:
#         cardio     variable value
# 0            0  cholesterol     0
# 1            1  cholesterol     1
# 2            1  cholesterol     1
# 3            1  cholesterol     0
# 4            0  cholesterol     0
# ...        ...          ...   ...
# 419995       0   overweight     1
# 419996       1   overweight     1
# 419997       1   overweight     1
# 419998       1   overweight     1
# 419999       0   overweight     1
#
# [420000 rows x 3 columns]

# %%
df_cat['total'] = 1
df_cat=df_cat.groupby(['cardio','variable','value'],as_index=False).count()

# %%
import seaborn as sns

# %%
fig = sns.catplot(x='variable',y='total',data = df_cat,hue='value',kind = 'bar',col='cardio').fig

# %%
fig.savefig('catplot.png')
fig

# %%
df_heat= df[   
(df['ap_lo'] <= df['ap_hi']) & 
(df['height'] >= df['height'].quantile(0.025))&
(df['height'] <= df['height'].quantile(0.975)) &
(df['weight'] >= df['weight'].quantile(0.025)) &
(df['weight'] <= df['weight'].quantile(0.975))
]

# %%
corr = df_heat.corr(method='pearson')
mask = np.triu(corr)
fig,ax =  plt.subplots(figsize=(12,12))
sns.heatmap(corr,linewidth=1,annot=True,square=True,mask=mask,fmt='.1f',center= 0.08,cbar_kws={'shrink':0.5})
# Out:
# <AxesSubplot:>
